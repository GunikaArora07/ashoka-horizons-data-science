# %% [markdown]
# <a href="https://colab.research.google.com/github/GunikaArora07/ashoka-horizons-data-science/blob/main/Week_3_assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./nutrition-food.csv' ,encoding='UTF-16')

# %%
df.head(5)
# Out:
#          Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0      Chonga Bagel        300       5.0          50           3            12
# 1      8-Grain Roll        380       6.0          70           7            10
# 2  Almond Croissant        410      22.0          45           3            10
# 3     Apple Fritter        460      23.0          56           2             7
# 4  Banana Nut Bread        420      22.0          52           2             6

# %%
df.tail(5)
# Out:
#                              Unnamed: 0   Calories   Fat (g)   Carb. (g)  \
# 108  Justin's Chocolate Hazelnut Butter        180      14.0          12
# 109      Justin's Classic Almond Butter        190      18.0           6
# 110                Lemon Chiffon Yogurt        340      13.0          38
# 111            Organic Avocado (Spread)         90       8.0           5
# 112                Seasonal Fruit Blend         90       0.0          24
#
#       Fiber (g)   Protein (g)
# 108           3             4
# 109           3             7
# 110           0            18
# 111           4             1
# 112           4             1

# %%
df.shape
# Out:
# (113, 6)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', ' Calories', ' Fat (g)', ' Carb. (g)', ' Fiber (g)',
#        ' Protein (g)'],
#       dtype='object')

# %%
df['Unnamed: 0'].unique(), df['Unnamed: 0'].nunique()
# Out:
# (array(['Chonga Bagel', '8-Grain Roll', 'Almond Croissant',
#         'Apple Fritter', 'Banana Nut Bread',
#         'Blueberry Muffin with Yogurt and Honey', 'Blueberry Scone',
#         'Butter Croissant', 'Butterfly Cookie', 'Cheese Danish',
#         'Chewy Chocolate Cookie', 'Chocolate Chip Cookie',
#         'Chocolate Chunk Muffin', 'Chocolate Croissant',
#         'Chocolate Hazelnut Croissant', 'Chocolate Marble Loaf Cake',
#         'Cinnamon Morning Bun', 'Cinnamon Raisin Bagel',
#         'Classic Coffee Cake', 'Cookie Butter Bar',
#         'Cranberry Orange Scone', "Devil's Food Doughnut",
#         'Double Chocolate Brownie', 'Double Chocolate Chunk Brownie',
#         'Double Chocolate Loaf Cake',
#         "Everybody's Favorite - Bantam Bagel (2 Pack)",
#         'Everything Bagel with Cheese', 'Frappuccino® Cookie Straw',
#         'French Toast - Bantam Bagels (2 Pack)',
#         'Gluten-Free Marshmallow Dream Bar', 'Ice Cream Cone Sugar Cookie',
# ...

# %%
df[' Carb. (g)'].unique(), df[' Carb. (g)'].nunique()
# Out:
# (array([50, 70, 45, 56, 52, 53, 61, 28, 38, 36, 30, 42, 60, 43, 64, 58, 57,
#         46, 55, 54, 14, 29, 68, 47, 40, 39, 18, 63, 67, 44, 23, 27, 80, 34,
#         33,  7,  9, 62, 31, 49, 24, 32, 41, 13, 35, 37, 12,  6,  5]),
#  49)

# %%
df[' Protein (g)'].unique(), df[' Protein (g)'].nunique()
# Out:
# (array([12, 10,  7,  6,  5,  2,  8,  4,  9,  3, 11,  1, 17, 19, 21, 13, 22,
#         32, 23, 16, 18, 24, 27, 20, 14, 15, 26, 29, 34]),
#  29)

# %%
df[' Fat (g)'].unique(), df[' Fat (g)'].nunique()
# Out:
# (array([ 5. ,  6. , 22. , 23. , 16. , 17. , 12. , 15. , 21. , 18. , 24. ,
#          1. , 28. ,  3.5,  3. ,  8. , 14. , 20. , 10. ,  4. , 27. ,  4.5,
#          1.5,  9. , 13. , 25. , 29. , 37. ,  7. , 26. , 32. , 19. ,  2.5,
#         30. ,  0. ]),
#  35)

# %%
df[' Fiber (g)'].unique(), df[' Fiber (g)'].nunique()
# Out:
# (array([ 3,  7,  2,  1,  0,  8, 10,  4,  6, 11,  5,  9, 21]), 13)

# %%
df[' Calories'].unique(), df[' Calories'].nunique()
# Out:
# (array([300, 380, 410, 460, 420, 240, 350, 320, 170, 310, 440, 330, 390,
#         490, 270, 360, 430, 100, 290,  90, 200, 250, 470, 480, 120, 280,
#         370, 180, 600, 130, 620, 530, 500, 560, 570, 450, 520, 160, 220,
#         230, 510, 650, 190, 340]),
#  44)

# %%
df.dtypes
# Out:
# Unnamed: 0       object
#  Calories         int64
#  Fat (g)        float64
#  Carb. (g)        int64
#  Fiber (g)        int64
#  Protein (g)      int64
# dtype: object

# %%
df[[' Calories']]
# Out:
#       Calories
# 0          300
# 1          380
# 2          410
# 3          460
# 4          420
# ..         ...
# 108        180
# 109        190
# 110        340
# 111         90
# 112         90
#
# [113 rows x 1 columns]

# %% [markdown]
# Data type- discrete as it contaisn nummerical values with no decimals

# %%
df[[' Carb. (g)']]
# Out:
#       Carb. (g)
# 0            50
# 1            70
# 2            45
# 3            56
# 4            52
# ..          ...
# 108          12
# 109           6
# 110          38
# 111           5
# 112          24
#
# [113 rows x 1 columns]

# %% [markdown]
# Data type- discrete as it contaisn nummerical values with no decimals

# %%
df[[' Fat (g)']]
# Out:
#       Fat (g)
# 0         5.0
# 1         6.0
# 2        22.0
# 3        23.0
# 4        22.0
# ..        ...
# 108      14.0
# 109      18.0
# 110      13.0
# 111       8.0
# 112       0.0
#
# [113 rows x 1 columns]

# %% [markdown]
# Data type- Continuous as it contains nummerical values with decimals

# %%
df[[' Protein (g)']]
# Out:
#       Protein (g)
# 0              12
# 1              10
# 2              10
# 3               7
# 4               6
# ..            ...
# 108             4
# 109             7
# 110            18
# 111             1
# 112             1
#
# [113 rows x 1 columns]

# %% [markdown]
# Data type- discrete as it contaisn nummerical values with no decimals

# %%
df[[' Fiber (g)']]
# Out:
#       Fiber (g)
# 0             3
# 1             7
# 2             3
# 3             2
# 4             2
# ..          ...
# 108           3
# 109           3
# 110           0
# 111           4
# 112           4
#
# [113 rows x 1 columns]

# %% [markdown]
# Data type- discrete as it contaisn nummerical values with no decimals

# %%
df[['Unnamed: 0']]
# Out:
#                              Unnamed: 0
# 0                          Chonga Bagel
# 1                          8-Grain Roll
# 2                      Almond Croissant
# 3                         Apple Fritter
# 4                      Banana Nut Bread
# ..                                  ...
# 108  Justin's Chocolate Hazelnut Butter
# 109      Justin's Classic Almond Butter
# 110                Lemon Chiffon Yogurt
# 111            Organic Avocado (Spread)
# 112                Seasonal Fruit Blend
#
# [113 rows x 1 columns]

# %% [markdown]
# Data type- nominal as it doesn't contain nummerical values and there is no order

# %%
df.isnull()
# Out:
#      Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0         False      False     False       False       False         False
# 1         False      False     False       False       False         False
# 2         False      False     False       False       False         False
# 3         False      False     False       False       False         False
# 4         False      False     False       False       False         False
# ..          ...        ...       ...         ...         ...           ...
# 108       False      False     False       False       False         False
# 109       False      False     False       False       False         False
# 110       False      False     False       False       False         False
# 111       False      False     False       False       False         False
# 112       False      False     False       False       False         False
#
# [113 rows x 6 columns]

# %%
df_rename = df.rename(columns={'Unnamed: 0':'Food_name', ' Calories' : ' Calories (kcal)', ' Carb. (g)': ' Carb (g)' })
df_rename
# Out:
#                               Food_name   Calories (kcal)   Fat (g)  \
# 0                          Chonga Bagel               300       5.0
# 1                          8-Grain Roll               380       6.0
# 2                      Almond Croissant               410      22.0
# 3                         Apple Fritter               460      23.0
# 4                      Banana Nut Bread               420      22.0
# ..                                  ...               ...       ...
# 108  Justin's Chocolate Hazelnut Butter               180      14.0
# 109      Justin's Classic Almond Butter               190      18.0
# 110                Lemon Chiffon Yogurt               340      13.0
# 111            Organic Avocado (Spread)                90       8.0
# 112                Seasonal Fruit Blend                90       0.0
#
#       Carb (g)   Fiber (g)   Protein (g)
# 0           50           3            12
# 1           70           7            10
# ...

# %%
df[' Calories'].max(), df[' Calories'].min(), df[' Calories'].mean(), df[' Calories'].std(), df[' Calories'].sum(), df[' Calories'].var()
# Out:
# (650, 90, 356.6371681415929, 127.71068460914907, 40300, 16310.018963337547)

# %%
df[' Carb. (g)'].min(), df[' Carb. (g)'].max(), df[' Carb. (g)'].mean(), df[' Carb. (g)'].std(), df[' Carb. (g)'].sum(), df[' Carb. (g)'].var()
# Out:
# (5, 80, 41.48672566371681, 15.796764499329662, 4688, 249.53776864728192)

# %%
df[' Fat (g)'].min(), df[' Fat (g)'].max(), df[' Fat (g)'].mean(), df[' Fat (g)'].std(), df[' Fat (g)'].sum(), df[' Fat (g)'].var()
# Out:
# (0.0, 37.0, 16.353982300884955, 8.297396702303574, 1848.0, 68.84679203539822)

# %%
df[' Fiber (g)'].min(), df[' Fiber (g)'].max(), df[' Fiber (g)'].mean(), df[' Fiber (g)'].std(), df[' Fiber (g)'].sum(), df[' Fiber (g)'].var()
# Out:
# (0, 21, 2.849557522123894, 2.8884660997851594, 322, 8.34323640960809)

# %%
df[' Protein (g)'].min(), df[' Protein (g)'].max(), df[' Protein (g)'].mean(), df[' Protein (g)'].std(), df[' Protein (g)'].sum(), df[' Protein (g)'].var()
# Out:
# (1, 34, 11.469026548672566, 8.46323012935978, 1296, 71.62626422250315)

# %%
proteins= df[' Protein (g)']
proteins
# Out:
# 0      12
# 1      10
# 2      10
# 3       7
# 4       6
#        ..
# 108     4
# 109     7
# 110    18
# 111     1
# 112     1
# Name:  Protein (g), Length: 113, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(proteins, bins=10)
# Out:
# (array([26., 28.,  9., 10.,  6., 11., 16.,  4.,  1.,  2.]),
#  array([ 1. ,  4.3,  7.6, 10.9, 14.2, 17.5, 20.8, 24.1, 27.4, 30.7, 34. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(proteins)
# Out:
# <Axes: ylabel=' Protein (g)'>

# %%
t

# %%
Fats= df[' Fat (g)']
Fats
# Out:
# 0       5.0
# 1       6.0
# 2      22.0
# 3      23.0
# 4      22.0
#        ...
# 108    14.0
# 109    18.0
# 110    13.0
# 111     8.0
# 112     0.0
# Name:  Fat (g), Length: 113, dtype: float64

# %%
plt.hist(Fats, bins=10)
# Out:
# (array([10., 10., 12., 12., 25., 14., 13., 14.,  2.,  1.]),
#  array([ 0. ,  3.7,  7.4, 11.1, 14.8, 18.5, 22.2, 25.9, 29.6, 33.3, 37. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(Fats)
# Out:
# <Axes: ylabel=' Fat (g)'>
