# %% [markdown]
# <a href="https://colab.research.google.com/github/GunikaArora07/ashoka-horizons-data-science/blob/main/My_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *I had made some changes in my file before importing it on google colab

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('My-Data.csv')

# %%
df.head(5)
# Out:
#                        Dish  calories  fats(g)  protein(g)  carbohydrates(g)  \
# 0  Avocado toast (2 slices)       195    11.00           5                20
# 1                 Spaghetti       790    29.00          26               107
# 2                    Rajma        318     1.25          21                57
# 3                      rice       323     0.70           7                70
# 4           pizza (12 inch)      1390    47.00          70               161
#
#    sodium(mg)  potassium(mg)  sugar(mg)  fibres(g)
# 0       150.0          425.0     1000.0        8.0
# 1       880.0            NaN        NaN        NaN
# 2       595.0         1008.0     4000.0       16.0
# 3       912.0           86.0      130.0        1.0
# 4      1930.0            0.0        NaN        NaN

# %%
df.tail(5)
# Out:
#               Dish  calories  fats(g)  protein(g)  carbohydrates(g)  \
# 2           Rajma        318     1.25          21                57
# 3             rice       323     0.70           7                70
# 4  pizza (12 inch)      1390    47.00          70               161
# 5     french toast       360     7.00          15                56
# 6    mango pudding       454    22.00           8                60
#
#    sodium(mg)  potassium(mg)  sugar(mg)  fibres(g)
# 2       595.0         1008.0     4000.0       16.0
# 3       912.0           86.0      130.0        1.0
# 4      1930.0            0.0        NaN        NaN
# 5       622.0          213.0        NaN        2.0
# 6         NaN            NaN       50.0        NaN

# %%
df.shape
# Out:
# (7, 9)

# %%
df.columns
# Out:
# Index(['Dish', 'calories', 'fats(g)', 'protein(g)', 'carbohydrates(g)',
#        'sodium(mg)', 'potassium(mg)', 'sugar(mg)', 'fibres(g)'],
#       dtype='object')

# %%
df['Dish'].unique(), df['Dish'].nunique()
# Out:
# (array(['Avocado toast (2 slices)', 'Spaghetti', 'Rajma ', 'rice',
#         'pizza (12 inch)', 'french toast', 'mango pudding'], dtype=object),
#  7)

# %%
df['calories'].unique(), df['calories'].nunique()
# Out:
# (array([ 195,  790,  318,  323, 1390,  360,  454]), 7)

# %%
df['fats(g)'].unique(), df['fats(g)'].nunique()
# Out:
# (array([11.  , 29.  ,  1.25,  0.7 , 47.  ,  7.  , 22.  ]), 7)

# %%
df['protein(g)'].unique(), df['protein(g)'].nunique
# Out:
# (array([ 5, 26, 21,  7, 70, 15,  8]),
#  <bound method IndexOpsMixin.nunique of 0     5
#  1    26
#  2    21
#  3     7
#  4    70
#  5    15
#  6     8
#  Name: protein(g), dtype: int64>)

# %%
df['carbohydrates(g)'].unique(), df['carbohydrates(g)'].nunique
# Out:
# (array([ 20, 107,  57,  70, 161,  56,  60]),
#  <bound method IndexOpsMixin.nunique of 0     20
#  1    107
#  2     57
#  3     70
#  4    161
#  5     56
#  6     60
#  Name: carbohydrates(g), dtype: int64>)

# %%
df['sodium(mg)'].unique(), df['sodium(mg)'].nunique
# Out:
# (array([ 150.,  880.,  595.,  912., 1930.,  622.,   nan]),
#  <bound method IndexOpsMixin.nunique of 0     150.0
#  1     880.0
#  2     595.0
#  3     912.0
#  4    1930.0
#  5     622.0
#  6       NaN
#  Name: sodium(mg), dtype: float64>)

# %%
df['potassium(mg)'].unique(), df['potassium(mg)'].nunique
# Out:
# (array([ 425.,   nan, 1008.,   86.,    0.,  213.]),
#  <bound method IndexOpsMixin.nunique of 0     425.0
#  1       NaN
#  2    1008.0
#  3      86.0
#  4       0.0
#  5     213.0
#  6       NaN
#  Name: potassium(mg), dtype: float64>)

# %%
df['fibres(g)'].unique(), df['fibres(g)'].nunique
# Out:
# (array([ 8., nan, 16.,  1.,  2.]),
#  <bound method IndexOpsMixin.nunique of 0     8.0
#  1     NaN
#  2    16.0
#  3     1.0
#  4     NaN
#  5     2.0
#  6     NaN
#  Name: fibres(g), dtype: float64>)

# %%
df.dtypes
# Out:
# Dish                 object
# calories              int64
# fats(g)             float64
# protein(g)            int64
# carbohydrates(g)      int64
# sodium(mg)          float64
# potassium(mg)       float64
# sugar(mg)           float64
# fibres(g)           float64
# dtype: object

# %%
df[['calories']]
# Out:
#    calories
# 0       195
# 1       790
# 2       318
# 3       323
# 4      1390
# 5       360
# 6       454

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['carbohydrates(g)']]
# Out:
#    carbohydrates(g)
# 0                20
# 1               107
# 2                57
# 3                70
# 4               161
# 5                56
# 6                60

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['fats(g)']]
# Out:
#    fats(g)
# 0    11.00
# 1    29.00
# 2     1.25
# 3     0.70
# 4    47.00
# 5     7.00
# 6    22.00

# %% [markdown]
# Data type- Continuous as it contains nummerical values with no decimals

# %%
df[['fibres(g)']]
# Out:
#    fibres(g)
# 0        8.0
# 1        NaN
# 2       16.0
# 3        1.0
# 4        NaN
# 5        2.0
# 6        NaN

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['protein(g)']]
# Out:
#    protein(g)
# 0           5
# 1          26
# 2          21
# 3           7
# 4          70
# 5          15
# 6           8

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['sodium(mg)']]
# Out:
#    sodium(mg)
# 0       150.0
# 1       880.0
# 2       595.0
# 3       912.0
# 4      1930.0
# 5       622.0
# 6         NaN

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['potassium(mg)']]
# Out:
#    potassium(mg)
# 0          425.0
# 1            NaN
# 2         1008.0
# 3           86.0
# 4            0.0
# 5          213.0
# 6            NaN

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['sugar(mg)']]
# Out:
#    sugar(mg)
# 0     1000.0
# 1        NaN
# 2     4000.0
# 3      130.0
# 4        NaN
# 5        NaN
# 6       50.0

# %% [markdown]
# Data type- Discrete as it contains nummerical values with no decimals

# %%
df[['Dish']]
# Out:
#                        Dish
# 0  Avocado toast (2 slices)
# 1                 Spaghetti
# 2                    Rajma
# 3                      rice
# 4           pizza (12 inch)
# 5              french toast
# 6             mango pudding

# %% [markdown]
# Data type- Nominal as it does not have nummerical values and there is no order.

# %%
df.isnull().sum()
# Out:
# Dish                0
# calories            0
# fats(g)             0
# protein(g)          0
# carbohydrates(g)    0
# sodium(mg)          1
# potassium(mg)       2
# sugar(mg)           3
# fibres(g)           3
# dtype: int64

# %%
np.where(df['sodium(mg)'].isnull())
# Out:
# (array([6]),)

# %%
np.where(df['potassium(mg)'].isnull())
# Out:
# (array([1, 6]),)

# %%
np.where(df['sugar(mg)'].isnull())
# Out:
# (array([1, 4, 5]),)

# %%
np.where(df['fibres(g)'].isnull())
# Out:
# (array([1, 4, 6]),)

# %%
df_new= df.dropna()
df_new
# Out:
#                        Dish  calories  fats(g)  protein(g)  carbohydrates(g)  \
# 0  Avocado toast (2 slices)       195    11.00           5                20
# 2                    Rajma        318     1.25          21                57
# 3                      rice       323     0.70           7                70
#
#    sodium(mg)  potassium(mg)  sugar(mg)  fibres(g)
# 0       150.0          425.0     1000.0        8.0
# 2       595.0         1008.0     4000.0       16.0
# 3       912.0           86.0      130.0        1.0

# %% [markdown]
# I was not sure of removing rows containing null values and belonging to different columns from the orignal data frame so I reffered to a site on google.
#  site referred- https://www.w3schools.com/

# %%
df_rename= df.rename(columns={'fibres(g)': 'fibre(g)', 'Dish': 'dish', 'calories': 'calories (kcal)'})
df_rename
# Out:
#                        dish  calories (kcal)  fats(g)  protein(g)  \
# 0  Avocado toast (2 slices)              195    11.00           5
# 1                 Spaghetti              790    29.00          26
# 2                    Rajma               318     1.25          21
# 3                      rice              323     0.70           7
# 4           pizza (12 inch)             1390    47.00          70
# 5              french toast              360     7.00          15
# 6             mango pudding              454    22.00           8
#
#    carbohydrates(g)  sodium(mg)  potassium(mg)  sugar(mg)  fibre(g)
# 0                20       150.0          425.0     1000.0       8.0
# 1               107       880.0            NaN        NaN       NaN
# 2                57       595.0         1008.0     4000.0      16.0
# 3                70       912.0           86.0      130.0       1.0
# 4               161      1930.0            0.0        NaN       NaN
# ...

# %%
df['calories'].max(), df['calories'].min(), df['calories'].mean(), df['calories'].std(), df['calories'].var(), df['calories'].sum()
# Out:
# (1390, 195, 547.1428571428571, 416.3005439068545, 173306.14285714287, 3830)

# %%
df['fats(g)'].max(), df['fats(g)'].min(), df['fats(g)'].mean(), df['fats(g)'].std(), df['fats(g)'].var(), df['fats(g)'].sum()
# Out:
# (47.0, 0.7, 16.85, 16.924316825207452, 286.43250000000006, 117.95)

# %%
df['protein(g)'].max(), df['protein(g)'].min(), df['protein(g)'].mean(), df['protein(g)'].std(), df['protein(g)'].var(), df['protein(g)'].sum()
# Out:
# (70, 5, 21.714285714285715, 22.654758776868388, 513.2380952380953, 152)

# %%
df['carbohydrates(g)'].max(), df['carbohydrates(g)'].min(), df['carbohydrates(g)'].mean(), df['carbohydrates(g)'].std(), df['carbohydrates(g)'].var(), df['carbohydrates(g)'].sum()
# Out:
# (161, 20, 75.85714285714286, 45.41449317647606, 2062.4761904761904, 531)

# %%
df['sodium(mg)'].max(), df['sodium(mg)'].min(), df['sodium(mg)'].mean(), df['sodium(mg)'].std(), df['sodium(mg)'].var(), df['sodium(mg)'].sum()
# Out:
# (1930.0,
#  150.0,
#  848.1666666666666,
#  596.3443356540471,
#  355626.5666666667,
#  5089.0)

# %%
df['potassium(mg)'].max(), df['potassium(mg)'].min(), df['potassium(mg)'].mean(), df['potassium(mg)'].std(), df['potassium(mg)'].var(), df['potassium(mg)'].sum()
# Out:
# (1008.0, 0.0, 346.4, 402.9544639286181, 162372.3, 1732.0)

# %%
df['sugar(mg)'].max(), df['sugar(mg)'].min(), df['sugar(mg)'].mean(), df['sugar(mg)'].std(), df['sugar(mg)'].var(), df['sugar(mg)'].sum()
# Out:
# (4000.0, 50.0, 1295.0, 1853.9417466576451, 3437100.0, 5180.0)

# %%
df['fibres(g)'].max(), df['fibres(g)'].min(), df['fibres(g)'].mean(), df['fibres(g)'].std(), df['fibres(g)'].var(), df['fibres(g)'].sum()
# Out:
# (16.0, 1.0, 6.75, 6.898067362191626, 47.583333333333336, 27.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sugars= df['sugar(mg)']
plt.hist(sugars, bins=10)
# Out:
# (array([2., 0., 1., 0., 0., 0., 0., 0., 0., 1.]),
#  array([  50.,  445.,  840., 1235., 1630., 2025., 2420., 2815., 3210.,
#         3605., 4000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(sugars)
# Out:
# <Axes: ylabel='sugar(mg)'>

# %%
sodium= df['sodium(mg)']
plt.hist(sodium, bins=10)
# Out:
# (array([1., 0., 2., 0., 2., 0., 0., 0., 0., 1.]),
#  array([ 150.,  328.,  506.,  684.,  862., 1040., 1218., 1396., 1574.,
#         1752., 1930.]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(sodium)
# Out:
# <Axes: ylabel='sodium(mg)'>
